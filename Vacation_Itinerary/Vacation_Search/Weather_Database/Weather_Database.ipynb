# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
# declare and empty list
city_data = []

#create counters
record_count = 1
set_count = 1

# %%
# Import the API key.
from apis import weather_api_key

# %%
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count += 1
    
    city_url = url + "&q=" + cities[i]

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description})

    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | charters towers
# Processing Record 4 of Set 1 | san patricio
# Processing Record 5 of Set 1 | goundam
# Processing Record 6 of Set 1 | jardim
# Processing Record 7 of Set 1 | elko
# Processing Record 8 of Set 1 | raudeberg
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | klaksvik
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | unidad
# Processing Record 13 of Set 1 | balabac
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | puli
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | morro bay
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | ozernovskiy
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | komsomolskiy
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | naze
# Processing Record 26 of Set 1 | praxedis guerrero
# Processing Record 27 of Set 1 | bendigo
# Processing Record 28 of Set 1 | punta gorda
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | port-cartier
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | sitka
# Processing Record 34 of Set 1 | shubarshi
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | kulhudhuffushi
# Processing Record 38 of Set 1 | broome
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | imisli
# City not found. Skipping...
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 1 | chumikan
# Processing Record 50 of Set 1 | dingle
# Processing Record 52 of Set 2 | saskylakh
# Processing Record 53 of Set 2 | upernavik
# Processing Record 54 of Set 2 | atasu
# Processing Record 55 of Set 2 | batsfjord
# Processing Record 56 of Set 2 | mnogovershinnyy
# Processing Record 57 of Set 2 | ukiah
# Processing Record 58 of Set 2 | atuona
# Processing Record 59 of Set 2 | kavieng
# Processing Record 60 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 61 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 62 of Set 2 | samarai
# Processing Record 63 of Set 2 | badin
# Processing Record 64 of Set 2 | yaan
# Processing Record 65 of Set 2 | port alfred
# Processing Record 66 of Set 2 | khatanga
# Processing Record 67 of Set 2 | hithadhoo
# Processing Record 68 of Set 2 | alice springs
# Processing Record 69 of Set 2 | ambatondrazaka
# Processing Record 70 of Set 2 | palmer
# Processing Record 71 of Set 2 | nemuro
# Processing Record 72 of Set 2 | fortuna
# Processing Record 73 of Set 2 | touros
# Processing Record 74 of Set 2 | gambat
# Processing Record 75 of Set 2 | airai
# Processing Record 76 of Set 2 | itarema
# Processing Record 77 of Set 2 | puerto ayora
# Processing Record 78 of Set 2 | los llanos de aridane
# Processing Record 79 of Set 2 | mizdah
# Processing Record 80 of Set 2 | albany
# Processing Record 81 of Set 2 | tombouctou
# Processing Record 82 of Set 2 | saldanha
# Processing Record 83 of Set 2 | pevek
# Processing Record 84 of Set 2 | luderitz
# Processing Record 85 of Set 2 | kavaratti
# Processing Record 86 of Set 2 | dikson
# Processing Record 87 of Set 2 | te anau
# Processing Record 88 of Set 2 | sorong
# Processing Record 89 of Set 2 | springbok
# Processing Record 90 of Set 2 | cape town
# Processing Record 91 of Set 2 | ushuaia
# Processing Record 92 of Set 2 | beyneu
# Processing Record 93 of Set 2 | saint-philippe
# Processing Record 94 of Set 2 | geraldton
# Processing Record 95 of Set 2 | sorland
# Processing Record 96 of Set 2 | grand gaube
# Processing Record 97 of Set 2 | kapaa
# Processing Record 98 of Set 2 | yellowknife
# Processing Record 99 of Set 2 | vardo
# Processing Record 100 of Set 2 | belaya gora
# Processing Record 101 of Set 2 | queanbeyan
# Processing Record 103 of Set 3 | dali
# Processing Record 104 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 105 of Set 3 | lazaro cardenas
# Processing Record 106 of Set 3 | maceio
# Processing Record 107 of Set 3 | castro
# Processing Record 108 of Set 3 | creel
# Processing Record 109 of Set 3 | sakaiminato
# Processing Record 110 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 111 of Set 3 | verkhnevilyuysk
# Processing Record 112 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 113 of Set 3 | arman
# Processing Record 114 of Set 3 | bereda
# Processing Record 115 of Set 3 | avarua
# Processing Record 116 of Set 3 | kodiak
# Processing Record 117 of Set 3 | sikeston
# Processing Record 118 of Set 3 | asau
# Processing Record 119 of Set 3 | kysyl-syr
# Processing Record 120 of Set 3 | kruisfontein
# Processing Record 121 of Set 3 | tuatapere
# Processing Record 122 of Set 3 | ponta do sol
# Processing Record 123 of Set 3 | east london
# Processing Record 124 of Set 3 | vitim
# Processing Record 125 of Set 3 | killybegs
# Processing Record 126 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 127 of Set 3 | clyde river
# Processing Record 128 of Set 3 | maple grove
# Processing Record 129 of Set 3 | kaitangata
# Processing Record 130 of Set 3 | nouakchott
# Processing Record 131 of Set 3 | neuquen
# Processing Record 132 of Set 3 | cidreira
# Processing Record 133 of Set 3 | hualmay
# Processing Record 134 of Set 3 | taoudenni
# Processing Record 135 of Set 3 | iqaluit
# Processing Record 136 of Set 3 | port hardy
# Processing Record 137 of Set 3 | rawson
# Processing Record 138 of Set 3 | utinga
# Processing Record 139 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 140 of Set 3 | martapura
# Processing Record 141 of Set 3 | norman wells
# Processing Record 142 of Set 3 | severo-kurilsk
# Processing Record 143 of Set 3 | ajdabiya
# Processing Record 144 of Set 3 | nogliki
# Processing Record 145 of Set 3 | mehamn
# Processing Record 146 of Set 3 | luwuk
# Processing Record 147 of Set 3 | hilo
# Processing Record 148 of Set 3 | chokurdakh
# Processing Record 149 of Set 3 | puerto madryn
# Processing Record 150 of Set 3 | butaritari
# Processing Record 151 of Set 3 | port keats
# Processing Record 152 of Set 3 | rundu
# Processing Record 154 of Set 4 | arraial do cabo
# Processing Record 155 of Set 4 | baijiantan
# Processing Record 156 of Set 4 | provideniya
# Processing Record 157 of Set 4 | victoria
# Processing Record 158 of Set 4 | cervo
# Processing Record 159 of Set 4 | sindand
# City not found. Skipping...
# Processing Record 160 of Set 4 | tautira
# Processing Record 161 of Set 4 | mar del plata
# Processing Record 162 of Set 4 | wuxue
# Processing Record 163 of Set 4 | san rafael
# Processing Record 164 of Set 4 | tsiroanomandidy
# Processing Record 165 of Set 4 | pisco
# Processing Record 166 of Set 4 | pedasi
# Processing Record 167 of Set 4 | lagoa
# Processing Record 168 of Set 4 | shulan
# Processing Record 169 of Set 4 | bengkulu
# Processing Record 170 of Set 4 | plettenberg bay
# Processing Record 171 of Set 4 | sur
# Processing Record 172 of Set 4 | kargasok
# Processing Record 173 of Set 4 | avera
# Processing Record 174 of Set 4 | vredendal
# Processing Record 175 of Set 4 | ust-maya
# Processing Record 176 of Set 4 | hasaki
# Processing Record 177 of Set 4 | dunn
# Processing Record 178 of Set 4 | upata
# Processing Record 179 of Set 4 | sakakah
# Processing Record 180 of Set 4 | boueni
# Processing Record 181 of Set 4 | inhambane
# Processing Record 182 of Set 4 | cabedelo
# Processing Record 183 of Set 4 | ndjole
# Processing Record 184 of Set 4 | volksrust
# Processing Record 185 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 186 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 187 of Set 4 | port moresby
# Processing Record 188 of Set 4 | kinkala
# Processing Record 189 of Set 4 | russell
# Processing Record 190 of Set 4 | pangnirtung
# Processing Record 191 of Set 4 | diffa
# Processing Record 192 of Set 4 | lusaka
# Processing Record 193 of Set 4 | vila franca do campo
# Processing Record 194 of Set 4 | juigalpa
# Processing Record 195 of Set 4 | praia
# Processing Record 196 of Set 4 | pacific grove
# Processing Record 197 of Set 4 | fare
# Processing Record 198 of Set 4 | kamiiso
# Processing Record 199 of Set 4 | barrow
# Processing Record 200 of Set 4 | kislovodsk
# Processing Record 201 of Set 4 | ambilobe
# Processing Record 202 of Set 4 | makaleng
# Processing Record 203 of Set 4 | codrington
# Processing Record 205 of Set 5 | santa rita
# Processing Record 206 of Set 5 | vangaindrano
# Processing Record 207 of Set 5 | kem
# Processing Record 208 of Set 5 | andselv
# City not found. Skipping...
# Processing Record 209 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 210 of Set 5 | portland
# Processing Record 211 of Set 5 | sibolga
# Processing Record 212 of Set 5 | lorengau
# Processing Record 213 of Set 5 | senneterre
# Processing Record 214 of Set 5 | front royal
# Processing Record 215 of Set 5 | sioux lookout
# Processing Record 216 of Set 5 | mitsamiouli
# Processing Record 217 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 218 of Set 5 | tiksi
# Processing Record 219 of Set 5 | inuvik
# Processing Record 220 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 221 of Set 5 | ilulissat
# Processing Record 222 of Set 5 | namikupa
# Processing Record 223 of Set 5 | krasnogorskoye
# Processing Record 224 of Set 5 | moose factory
# Processing Record 225 of Set 5 | pedernales
# Processing Record 226 of Set 5 | lae
# Processing Record 227 of Set 5 | new norfolk
# Processing Record 228 of Set 5 | dunda
# Processing Record 229 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 230 of Set 5 | maumere
# Processing Record 231 of Set 5 | manakara
# Processing Record 232 of Set 5 | west bay
# Processing Record 233 of Set 5 | kieta
# Processing Record 234 of Set 5 | ahipara
# Processing Record 235 of Set 5 | torbay
# Processing Record 236 of Set 5 | saint george
# Processing Record 237 of Set 5 | ilinskoye-khovanskoye
# Processing Record 238 of Set 5 | cherskiy
# Processing Record 239 of Set 5 | kahului
# Processing Record 240 of Set 5 | esperance
# Processing Record 241 of Set 5 | port elizabeth
# Processing Record 242 of Set 5 | derzhavinsk
# Processing Record 243 of Set 5 | saint-georges
# Processing Record 244 of Set 5 | kanker
# Processing Record 245 of Set 5 | champasak
# Processing Record 246 of Set 5 | sidi ali
# Processing Record 247 of Set 5 | olafsvik
# Processing Record 248 of Set 5 | thohoyandou
# Processing Record 249 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 250 of Set 5 | sao joao da barra
# Processing Record 251 of Set 5 | timra
# Processing Record 252 of Set 5 | gagino
# Processing Record 253 of Set 5 | okhotsk
# Processing Record 254 of Set 5 | hereford
# Processing Record 256 of Set 6 | tasiilaq
# Processing Record 257 of Set 6 | tsumeb
# Processing Record 258 of Set 6 | kurumkan
# Processing Record 259 of Set 6 | tuktoyaktuk
# Processing Record 260 of Set 6 | yar-sale
# Processing Record 261 of Set 6 | mount gambier
# Processing Record 262 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 263 of Set 6 | fairbanks
# Processing Record 264 of Set 6 | ban nahin
# Processing Record 265 of Set 6 | yerbogachen
# Processing Record 266 of Set 6 | harper
# Processing Record 267 of Set 6 | rio branco
# Processing Record 268 of Set 6 | deputatskiy
# Processing Record 269 of Set 6 | banda aceh
# Processing Record 270 of Set 6 | amuntai
# Processing Record 271 of Set 6 | faanui
# Processing Record 272 of Set 6 | yurla
# Processing Record 273 of Set 6 | hobyo
# Processing Record 274 of Set 6 | bambous virieux
# Processing Record 275 of Set 6 | saint-joseph
# Processing Record 276 of Set 6 | lukovetskiy
# Processing Record 277 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 278 of Set 6 | gimli
# Processing Record 279 of Set 6 | beamsville
# Processing Record 280 of Set 6 | inndyr
# Processing Record 281 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 282 of Set 6 | bose
# Processing Record 283 of Set 6 | zapolyarnyy
# Processing Record 284 of Set 6 | denpasar
# Processing Record 285 of Set 6 | huilong
# Processing Record 286 of Set 6 | aklavik
# Processing Record 287 of Set 6 | karatau
# Processing Record 288 of Set 6 | quatre cocos
# Processing Record 289 of Set 6 | plover
# Processing Record 290 of Set 6 | brae
# Processing Record 291 of Set 6 | fallon
# Processing Record 292 of Set 6 | apiai
# Processing Record 293 of Set 6 | kalomo
# City not found. Skipping...
# Processing Record 294 of Set 6 | carutapera
# Processing Record 295 of Set 6 | saint-leu
# Processing Record 296 of Set 6 | umm kaddadah
# Processing Record 297 of Set 6 | haines junction
# Processing Record 298 of Set 6 | ciresu
# Processing Record 299 of Set 6 | namibe
# Processing Record 300 of Set 6 | saint-pierre
# Processing Record 301 of Set 6 | sokoni
# Processing Record 302 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 303 of Set 6 | dauriya
# Processing Record 304 of Set 6 | moissac
# Processing Record 305 of Set 6 | nome
# Processing Record 307 of Set 7 | ancud
# Processing Record 308 of Set 7 | yeniseysk
# Processing Record 309 of Set 7 | buchanan
# Processing Record 310 of Set 7 | iranshahr
# Processing Record 311 of Set 7 | husavik
# Processing Record 312 of Set 7 | souillac
# Processing Record 313 of Set 7 | barguzin
# Processing Record 314 of Set 7 | tarko-sale
# Processing Record 315 of Set 7 | caibarien
# Processing Record 316 of Set 7 | kaabong
# Processing Record 317 of Set 7 | kapit
# Processing Record 318 of Set 7 | guane
# Processing Record 319 of Set 7 | lopik
# Processing Record 320 of Set 7 | yulara
# Processing Record 321 of Set 7 | roanoke rapids
# Processing Record 322 of Set 7 | vila velha
# Processing Record 323 of Set 7 | boralday
# Processing Record 324 of Set 7 | bonavista
# Processing Record 325 of Set 7 | takoradi
# Processing Record 326 of Set 7 | moree
# Processing Record 327 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 328 of Set 7 | feni
# Processing Record 329 of Set 7 | beringovskiy
# Processing Record 330 of Set 7 | chara
# Processing Record 331 of Set 7 | bay roberts
# Processing Record 332 of Set 7 | caravelas
# Processing Record 333 of Set 7 | hamilton
# Processing Record 334 of Set 7 | sao filipe
# Processing Record 335 of Set 7 | nelson bay
# Processing Record 336 of Set 7 | gibara
# Processing Record 337 of Set 7 | mayo
# Processing Record 338 of Set 7 | carlsbad
# Processing Record 339 of Set 7 | saint anthony
# Processing Record 340 of Set 7 | aksarka
# Processing Record 341 of Set 7 | lhokseumawe
# Processing Record 342 of Set 7 | byron bay
# Processing Record 343 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 344 of Set 7 | giraltovce
# Processing Record 345 of Set 7 | aban
# Processing Record 346 of Set 7 | kawalu
# Processing Record 347 of Set 7 | labuhan
# Processing Record 348 of Set 7 | bullerup
# Processing Record 349 of Set 7 | batagay-alyta
# Processing Record 350 of Set 7 | naples
# Processing Record 351 of Set 7 | banjar
# Processing Record 352 of Set 7 | rampur hat
# Processing Record 353 of Set 7 | aromashevo
# Processing Record 354 of Set 7 | the valley
# Processing Record 355 of Set 7 | abha
# Processing Record 356 of Set 7 | hermosillo
# Processing Record 358 of Set 8 | sinnamary
# Processing Record 359 of Set 8 | manjacaze
# Processing Record 360 of Set 8 | islamkot
# Processing Record 361 of Set 8 | narsaq
# Processing Record 362 of Set 8 | balad
# Processing Record 363 of Set 8 | poum
# Processing Record 364 of Set 8 | sumbe
# Processing Record 365 of Set 8 | kirakira
# Processing Record 366 of Set 8 | morant bay
# Processing Record 367 of Set 8 | north platte
# Processing Record 368 of Set 8 | marystown
# Processing Record 369 of Set 8 | myanaung
# Processing Record 370 of Set 8 | constitucion
# Processing Record 371 of Set 8 | seinajoki
# Processing Record 372 of Set 8 | cacador
# Processing Record 373 of Set 8 | katobu
# Processing Record 374 of Set 8 | keningau
# Processing Record 375 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 376 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 377 of Set 8 | kosonsoy
# Processing Record 378 of Set 8 | ulladulla
# Processing Record 379 of Set 8 | aquiraz
# Processing Record 380 of Set 8 | pathanamthitta
# Processing Record 381 of Set 8 | general roca
# Processing Record 382 of Set 8 | drammen
# Processing Record 383 of Set 8 | smithers
# Processing Record 384 of Set 8 | necochea
# Processing Record 385 of Set 8 | abiy adi
# City not found. Skipping...
# Processing Record 386 of Set 8 | bani
# Processing Record 387 of Set 8 | nuevo casas grandes
# Processing Record 388 of Set 8 | flinders
# Processing Record 389 of Set 8 | talnakh
# Processing Record 390 of Set 8 | college
# Processing Record 391 of Set 8 | goure
# Processing Record 392 of Set 8 | bathsheba
# Processing Record 393 of Set 8 | bo rai
# Processing Record 394 of Set 8 | hay river
# Processing Record 395 of Set 8 | saint-louis
# Processing Record 396 of Set 8 | katete
# Processing Record 397 of Set 8 | eyl
# Processing Record 398 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 399 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 400 of Set 8 | la ronge
# Processing Record 401 of Set 8 | centralina
# Processing Record 402 of Set 8 | ustek
# Processing Record 403 of Set 8 | lima
# Processing Record 404 of Set 8 | maracacume
# Processing Record 405 of Set 8 | lavrentiya
# Processing Record 406 of Set 8 | hami
# Processing Record 407 of Set 8 | santa fe
# Processing Record 409 of Set 9 | isangel
# Processing Record 410 of Set 9 | krasnoselkup
# Processing Record 411 of Set 9 | gillette
# Processing Record 412 of Set 9 | goderich
# Processing Record 413 of Set 9 | tumpat
# Processing Record 414 of Set 9 | georgetown
# Processing Record 415 of Set 9 | dengzhou
# Processing Record 416 of Set 9 | amapa
# Processing Record 417 of Set 9 | turukhansk
# Processing Record 418 of Set 9 | gaoual
# Processing Record 419 of Set 9 | xam nua
# Processing Record 420 of Set 9 | hambantota
# Processing Record 421 of Set 9 | cockburn town
# Processing Record 422 of Set 9 | fernley
# Processing Record 423 of Set 9 | lushunkou
# City not found. Skipping...
# Processing Record 424 of Set 9 | polunochnoye
# Processing Record 425 of Set 9 | seddon
# Processing Record 426 of Set 9 | hovd
# Processing Record 427 of Set 9 | haljala
# Processing Record 428 of Set 9 | namatanai
# Processing Record 429 of Set 9 | alta gracia
# Processing Record 430 of Set 9 | hofn
# Processing Record 431 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 432 of Set 9 | sabha
# Processing Record 433 of Set 9 | baykit
# Processing Record 434 of Set 9 | san andres del rabanedo
# Processing Record 435 of Set 9 | ugoofaaru
# Processing Record 436 of Set 9 | le vauclin
# Processing Record 437 of Set 9 | huangmei
# Processing Record 438 of Set 9 | moerai
# Processing Record 439 of Set 9 | brainerd
# Processing Record 440 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 441 of Set 9 | sierra vista
# Processing Record 442 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 443 of Set 9 | ciudad bolivar
# Processing Record 444 of Set 9 | obo
# Processing Record 445 of Set 9 | taicheng
# Processing Record 446 of Set 9 | hervey bay
# Processing Record 447 of Set 9 | riyadh
# Processing Record 448 of Set 9 | san jeronimo
# Processing Record 449 of Set 9 | leua
# Processing Record 450 of Set 9 | thatta
# Processing Record 451 of Set 9 | santa rosalia
# Processing Record 452 of Set 9 | strezhevoy
# Processing Record 453 of Set 9 | puerto maldonado
# Processing Record 454 of Set 9 | havoysund
# Processing Record 455 of Set 9 | crotone
# Processing Record 456 of Set 9 | nanakuli
# Processing Record 457 of Set 9 | kibakwe
# Processing Record 458 of Set 9 | marquette
# Processing Record 460 of Set 10 | sabang
# Processing Record 461 of Set 10 | naziya
# Processing Record 462 of Set 10 | correntina
# Processing Record 463 of Set 10 | spearfish
# Processing Record 464 of Set 10 | changji
# Processing Record 465 of Set 10 | oistins
# Processing Record 466 of Set 10 | praya
# Processing Record 467 of Set 10 | agadir
# Processing Record 468 of Set 10 | effium
# Processing Record 469 of Set 10 | vao
# Processing Record 470 of Set 10 | libertador general san martin
# Processing Record 471 of Set 10 | mangan
# Processing Record 472 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 473 of Set 10 | ostrovnoy
# Processing Record 474 of Set 10 | richards bay
# Processing Record 475 of Set 10 | san roque
# Processing Record 476 of Set 10 | singaparna
# Processing Record 477 of Set 10 | flin flon
# Processing Record 478 of Set 10 | sala
# Processing Record 479 of Set 10 | barroquinha
# Processing Record 480 of Set 10 | gaomi
# Processing Record 481 of Set 10 | moron
# Processing Record 482 of Set 10 | sao felix do xingu
# Processing Record 483 of Set 10 | nanyamba
# Processing Record 484 of Set 10 | masalli
# Processing Record 485 of Set 10 | mezhdurechensk
# Processing Record 486 of Set 10 | mount isa
# Processing Record 487 of Set 10 | culebra
# Processing Record 488 of Set 10 | palmeiras de goias
# Processing Record 489 of Set 10 | half moon bay
# Processing Record 490 of Set 10 | faya
# Processing Record 491 of Set 10 | nuuk
# Processing Record 492 of Set 10 | bubaque
# Processing Record 493 of Set 10 | potsdam
# Processing Record 494 of Set 10 | lakatoro
# Processing Record 495 of Set 10 | loa janan
# Processing Record 496 of Set 10 | sulangan
# Processing Record 497 of Set 10 | broken hill
# Processing Record 498 of Set 10 | aswan
# Processing Record 499 of Set 10 | esquipulas
# Processing Record 500 of Set 10 | moroni
# Processing Record 501 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 502 of Set 10 | pag
# Processing Record 503 of Set 10 | atar
# Processing Record 504 of Set 10 | adre
# Processing Record 505 of Set 10 | shurugwi
# Processing Record 506 of Set 10 | khonsa
# Processing Record 507 of Set 10 | takaka
# Processing Record 508 of Set 10 | tashara
# Processing Record 509 of Set 10 | huarmey
# Processing Record 511 of Set 11 | kununurra
# Processing Record 512 of Set 11 | tshikapa
# Processing Record 513 of Set 11 | garowe
# Processing Record 514 of Set 11 | mezen
# Processing Record 515 of Set 11 | eureka
# Processing Record 516 of Set 11 | turayf
# Processing Record 517 of Set 11 | kaeng khlo
# City not found. Skipping...
# Processing Record 518 of Set 11 | muros
# Processing Record 519 of Set 11 | vyartsilya
# Processing Record 520 of Set 11 | jingdezhen
# Processing Record 521 of Set 11 | seoul
# Processing Record 522 of Set 11 | srednekolymsk
# Processing Record 523 of Set 11 | karaton
# Processing Record 524 of Set 11 | lompoc
# Processing Record 525 of Set 11 | ucluelet
# Processing Record 526 of Set 11 | maymyo
# Processing Record 527 of Set 11 | kaeo
# Processing Record 528 of Set 11 | novoderevyankovskaya
# Processing Record 529 of Set 11 | bone
# Processing Record 530 of Set 11 | nishihara
# Processing Record 531 of Set 11 | jodhpur
# Processing Record 532 of Set 11 | lillooet
# Processing Record 533 of Set 11 | karakol
# Processing Record 534 of Set 11 | nalut
# Processing Record 535 of Set 11 | xuddur
# Processing Record 536 of Set 11 | gizo
# Processing Record 537 of Set 11 | matara
# Processing Record 538 of Set 11 | clarence town
# Processing Record 539 of Set 11 | el alto
# Processing Record 540 of Set 11 | campos do jordao
# Processing Record 541 of Set 11 | sungaipenuh
# Processing Record 542 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 543 of Set 11 | konstantinovka
# Processing Record 544 of Set 11 | hammerfest
# Processing Record 545 of Set 11 | iglino
# Processing Record 546 of Set 11 | akyab
# Processing Record 547 of Set 11 | leningradskiy
# Processing Record 548 of Set 11 | alekseyevsk
# Processing Record 549 of Set 11 | gari
# Processing Record 550 of Set 11 | picota
# Processing Record 551 of Set 11 | ballina
# Processing Record 552 of Set 11 | gbarnga
# Processing Record 553 of Set 11 | zhezkazgan
# Processing Record 554 of Set 11 | maragogi
# Processing Record 555 of Set 11 | salalah
# Processing Record 556 of Set 11 | roald
# Processing Record 557 of Set 11 | toul
# Processing Record 558 of Set 11 | iseyin
# Processing Record 559 of Set 11 | wausau
# Processing Record 560 of Set 11 | atambua
# Processing Record 562 of Set 12 | vila
# Processing Record 563 of Set 12 | kingsland
# Processing Record 564 of Set 12 | emerald
# Processing Record 565 of Set 12 | iguape
# Processing Record 566 of Set 12 | mecca
# Processing Record 567 of Set 12 | gigmoto
# Processing Record 568 of Set 12 | tarakan
# Processing Record 569 of Set 12 | buala
# Processing Record 570 of Set 12 | ust-nera
# Processing Record 571 of Set 12 | kirovskiy
# Processing Record 572 of Set 12 | roros
# Processing Record 573 of Set 12 | keuruu
# Processing Record 574 of Set 12 | honiara
# Processing Record 575 of Set 12 | solok
# Processing Record 576 of Set 12 | san quintin
# Processing Record 577 of Set 12 | dembi dolo
# Processing Record 578 of Set 12 | nefteyugansk
# Processing Record 579 of Set 12 | pindushi
# Processing Record 580 of Set 12 | lata
# Processing Record 581 of Set 12 | keti bandar
# Processing Record 582 of Set 12 | waterfoot
# Processing Record 583 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 584 of Set 12 | pochutla
# Processing Record 585 of Set 12 | maryborough
# Processing Record 586 of Set 12 | matongo
# Processing Record 587 of Set 12 | greenville
# Processing Record 588 of Set 12 | salinas
# Processing Record 589 of Set 12 | payyannur
# Processing Record 590 of Set 12 | camacha
# Processing Record 591 of Set 12 | khanpur
# Processing Record 592 of Set 12 | tucuman
# Processing Record 593 of Set 12 | bilma
# Processing Record 594 of Set 12 | mandalgovi
# Processing Record 595 of Set 12 | sault sainte marie
# Processing Record 596 of Set 12 | burriana
# Processing Record 597 of Set 12 | sao gabriel da cachoeira
# Processing Record 598 of Set 12 | khorinsk
# Processing Record 599 of Set 12 | great yarmouth
# Processing Record 600 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 601 of Set 12 | semirara
# Processing Record 602 of Set 12 | novita
# Processing Record 603 of Set 12 | shenjiamen
# Processing Record 604 of Set 12 | constantine
# Processing Record 605 of Set 12 | luanda
# Processing Record 606 of Set 12 | ye
# City not found. Skipping...
# Processing Record 607 of Set 12 | solnechnyy
# Processing Record 608 of Set 12 | marzuq
# Processing Record 609 of Set 12 | igatpuri
# Processing Record 610 of Set 12 | kutum
# Processing Record 611 of Set 12 | nago
# Processing Record 613 of Set 13 | soe
# Processing Record 614 of Set 13 | cayenne
# Processing Record 615 of Set 13 | kurilsk
# Processing Record 616 of Set 13 | conceicao do araguaia
# Processing Record 617 of Set 13 | san pedro
# Processing Record 618 of Set 13 | port-gentil
# Processing Record 619 of Set 13 | ingham
# Processing Record 620 of Set 13 | svetlogorsk
# Processing Record 621 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 622 of Set 13 | lasa
# Processing Record 623 of Set 13 | pleasanton
# Processing Record 624 of Set 13 | terney
# Processing Record 625 of Set 13 | fort nelson
# Processing Record 626 of Set 13 | brookings
# Processing Record 627 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 628 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 629 of Set 13 | guerrero negro
# Processing Record 630 of Set 13 | zhanaozen
# Processing Record 631 of Set 13 | margate
# Processing Record 632 of Set 13 | dongsheng
# Processing Record 633 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 634 of Set 13 | havelock
# Processing Record 635 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 636 of Set 13 | gonda
# Processing Record 637 of Set 13 | mbalmayo
# Processing Record 638 of Set 13 | yeppoon
# Processing Record 639 of Set 13 | rognan
# Processing Record 640 of Set 13 | dalirig
# Processing Record 641 of Set 13 | beloha
# Processing Record 642 of Set 13 | falmouth
# Processing Record 643 of Set 13 | manokwari
# Processing Record 644 of Set 13 | waipawa
# Processing Record 645 of Set 13 | hulst
# Processing Record 646 of Set 13 | yokadouma
# Processing Record 647 of Set 13 | road town
# Processing Record 648 of Set 13 | tamiahua
# Processing Record 649 of Set 13 | dodge city
# Processing Record 650 of Set 13 | lyngseidet
# Processing Record 651 of Set 13 | lyubuchany
# Processing Record 652 of Set 13 | gorontalo
# Processing Record 653 of Set 13 | rebrikha
# Processing Record 654 of Set 13 | mastic beach
# Processing Record 655 of Set 13 | voyvozh
# Processing Record 656 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 657 of Set 13 | balakhninskiy
# Processing Record 658 of Set 13 | paita
# Processing Record 659 of Set 13 | blagoyevo
# Processing Record 660 of Set 13 | esso
# Processing Record 661 of Set 13 | desna
# Processing Record 662 of Set 13 | port blair
# Processing Record 664 of Set 14 | tateyama
# Processing Record 665 of Set 14 | bosaso
# Processing Record 666 of Set 14 | berdigestyakh
# Processing Record 667 of Set 14 | florianopolis
# Processing Record 668 of Set 14 | kungurtug
# Processing Record 669 of Set 14 | bolitoc
# Processing Record 670 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 671 of Set 14 | morondava
# Processing Record 672 of Set 14 | chunoyar
# Processing Record 673 of Set 14 | qui nhon
# Processing Record 674 of Set 14 | nouadhibou
# Processing Record 675 of Set 14 | alofi
# Processing Record 676 of Set 14 | novi sanzhary
# Processing Record 677 of Set 14 | kaoma
# Processing Record 678 of Set 14 | colonelganj
# Processing Record 679 of Set 14 | kabo
# Processing Record 680 of Set 14 | ojinaga
# Processing Record 681 of Set 14 | nanortalik
# Processing Record 682 of Set 14 | xichang
# Processing Record 683 of Set 14 | mineros
# Processing Record 684 of Set 14 | kichera
# Processing Record 685 of Set 14 | santa cruz
# Processing Record 686 of Set 14 | ixtapa
# Processing Record 687 of Set 14 | tianpeng
# Processing Record 688 of Set 14 | east cleveland
# Processing Record 689 of Set 14 | dauphin
# Processing Record 690 of Set 14 | antofagasta
# Processing Record 691 of Set 14 | bijie
# Processing Record 692 of Set 14 | santa ana
# Processing Record 693 of Set 14 | peniche
# Processing Record 694 of Set 14 | sandpoint
# Processing Record 695 of Set 14 | grindavik
# Processing Record 696 of Set 14 | san cristobal
# Processing Record 697 of Set 14 | gambiran
# Processing Record 698 of Set 14 | presidencia roque saenz pena
# Processing Record 699 of Set 14 | acapulco
# Processing Record 700 of Set 14 | boa vista
# Processing Record 701 of Set 14 | kalabo
# Processing Record 702 of Set 14 | yamoto
# Processing Record 703 of Set 14 | igarka
# Processing Record 704 of Set 14 | meulaboh
# Processing Record 705 of Set 14 | homer
# Processing Record 706 of Set 14 | oranjemund
# Processing Record 707 of Set 14 | barra dos coqueiros
# Processing Record 708 of Set 14 | serenje
# Processing Record 709 of Set 14 | coquimbo
# Processing Record 710 of Set 14 | mbacke
# City not found. Skipping...
# Processing Record 711 of Set 14 | usinsk
# Processing Record 712 of Set 14 | nha trang
# Processing Record 713 of Set 14 | pacifica
# Processing Record 715 of Set 15 | vysokogornyy
# Processing Record 716 of Set 15 | marietta
# Processing Record 717 of Set 15 | pokhara
# Processing Record 718 of Set 15 | pathein
# Processing Record 719 of Set 15 | daxian
# City not found. Skipping...
# Processing Record 720 of Set 15 | zeya
# Processing Record 721 of Set 15 | puerto carreno
# Processing Record 722 of Set 15 | bayanday
# Processing Record 723 of Set 15 | sterling
# Processing Record 724 of Set 15 | vostok
# Processing Record 725 of Set 15 | sakaraha
# Processing Record 726 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 727 of Set 15 | patitirion
# Processing Record 728 of Set 15 | burkburnett
# Processing Record 729 of Set 15 | kloulklubed
# Processing Record 730 of Set 15 | port shepstone

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Rikitea      PF -23.1203 -134.9692     79.93        67
# 1    Charters Towers      AU -20.1000  146.2667     84.96        52
# 2       San Patricio      US  28.0170  -97.5169     53.17        66
# 3            Goundam      ML  16.4145   -3.6708     68.76        17
# 4             Jardim      BR -21.4803  -56.1381     73.96        93
# ..               ...     ...      ...       ...       ...       ...
# 659         Sakaraha      MG -22.9000   44.5333     71.69        94
# 660       Patitirion      GR  39.1500   23.8667     39.00        50
# 661      Burkburnett      US  34.0979  -98.5706     44.01        56
# 662      Kloulklubed      PW   7.0419  134.2556     81.86        80
# 663   Port Shepstone      ZA -30.7414   30.4550     70.29        84
#
#      Cloudiness  Wind Speed Current Description
# 0            23        4.90          light rain
# 1           100       12.28     overcast clouds
# 2           100        6.87     overcast clouds
# 3             0        9.78           clear sky
# 4           100        5.14     overcast clouds
# ..          ...         ...                 ...
# 659          33        1.03    scattered clouds
# 660          70        5.99       broken clouds
# 661           1        9.22           clear sky
# 662         100       20.22     overcast clouds
# 663          99        6.15          light rain
#
# [664 rows x 9 columns]

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.1203 -134.9692     79.93        67          23
# 1  Charters Towers      AU -20.1000  146.2667     84.96        52         100
# 2     San Patricio      US  28.0170  -97.5169     53.17        66         100
# 3          Goundam      ML  16.4145   -3.6708     68.76        17           0
# 4           Jardim      BR -21.4803  -56.1381     73.96        93         100
# 5             Elko      US  41.0002 -115.5012     44.60        49          90
# 6        Raudeberg      NO  61.9875    5.1352     33.06        87          97
# 7          Mataura      NZ -46.1927  168.8643     48.00        80         100
# 8         Klaksvik      FO  62.2266   -6.5890     37.85        74          38
# 9          Qaanaaq      GL  77.4840  -69.3632    -13.38        65           0
#
#    Wind Speed Current Description
# 0        4.90          light rain
# 1       12.28     overcast clouds
# 2        6.87     overcast clouds
# 3        9.78           clear sky
# 4        5.14     overcast clouds
# 5        6.91     overcast clouds
# 6       20.78     overcast clouds
# 7        8.01     overcast clouds
# 8       23.71    scattered clouds
# 9        7.02           clear sky

# %%
# create the output file (csv)
output_data_file = "WeatherPy_Database.csv"

# export the city data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
